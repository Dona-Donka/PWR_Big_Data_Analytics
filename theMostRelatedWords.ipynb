# %%
import findspark
findspark.init()
import pyspark
from pyspark import SparkContext
sc = pyspark.SparkContext.getOrCreate()
from collections import Counter


# reading a text, getting lines
with open ("/home/dona/Pulpit/BigDataAlgorithms/lab02/chapter_I") as myfile:
    wordList = myfile.read().split()

type(wordList)
relatedWords = []
for i in range(len(wordList)-1):
    item = str(wordList[i] + " " + wordList[i+1])
    relatedWords.append(item)
    
print(type(relatedWords))
relatedWords = Counter(relatedWords)
print(relatedWords)
# Out:
# <class 'list'>
# ...
